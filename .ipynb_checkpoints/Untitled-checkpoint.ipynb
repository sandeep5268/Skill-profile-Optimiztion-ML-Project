# %%
# Core
import os
from pathlib import Path
import joblib

# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing & splitting
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Models
from sklearn.linear_model import (
    Ridge,
    ElasticNet,
    Lasso,
    TheilSenRegressor
)
from sklearn.ensemble import (
    ExtraTreesRegressor,
    StackingRegressor
)

# Metrics
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
MODEL_DIR = "models"
RESULTS_DIR = "results"

Path(MODEL_DIR).mkdir(exist_ok=True)
Path(RESULTS_DIR).mkdir(exist_ok=True)

# %%
def load_dataset(file_path):
    """Load the dataset from a CSV file."""
    try:
        df = pd.read_csv(file_path)
        print(f"Dataset loaded successfully with shape: {df.shape}")
        return df
    except FileNotFoundError:
        print(f"Error: File {file_path} not found.")
        return None
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return None

# %%
MODEL_DIR = "models"
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
df = pd.read_csv('Dataset/resume_skills_vs_interview_calls.csv')
df
# Out:
#     candidate_id degree  years_experience  projects_count  certifications  \
# 0           C001  BTech                 0              11               2
# 1           C002  BTech                 8               1               4
# 2           C003    BSc                 3               8               4
# 3           C004    MCA                 4              12               6
# 4           C005  MTech                 2               3               6
# ..           ...    ...               ...             ...             ...
# 195         C196  MTech                 0               5               2
# 196         C197    BSc                 3               2               1
# 197         C198  BTech                 5              12               4
# 198         C199    BSc                 2              11               3
# 199         C200    BSc                 7               9               2
#
#      skills_count internship github_portfolio  resume_score  interview_calls
# 0              11        Yes              Yes            89                6
# 1              17        Yes              Yes           100                6
# 2               4        Yes               No            89                4
# 3               4        Yes               No           100                7
# 4              14        Yes              Yes            96                6
# ..            ...        ...              ...           ...              ...
# 195             9        Yes               No            70                3
# 196             6         No              Yes            70                4
# 197             8         No              Yes           100                6
# 198             5         No               No            84                6
# 199            18        Yes              Yes           100                7
#
# [200 rows x 10 columns]

# %%
MODEL_DIR = "models"
os.makedirs(MODEL_DIR, exist_ok=True)


def preprocess_data(df, is_train=True):
    df = df.copy()

    # -----------------------------
    # Drop ID Column
    # -----------------------------
    if 'candidate_id' in df.columns:
        df.drop(columns=['candidate_id'], inplace=True)

    # -----------------------------
    # Encode Categorical Features
    # -----------------------------
    categorical_cols = [
        'degree',
        'internship',
        'github_portfolio'
    ]

    for col in categorical_cols:
        encoder_path = os.path.join(MODEL_DIR, f"{col}_encoder.pkl")

        if is_train:
            le = LabelEncoder()
            df[col] = le.fit_transform(df[col].astype(str))
            joblib.dump(le, encoder_path)
        else:
            le = joblib.load(encoder_path)
            df[col] = le.transform(df[col].astype(str))

    # -----------------------------
    # Feature Matrix
    # -----------------------------
    X = df.drop(columns=['resume_score'])

    # -----------------------------
    # Standard Scaling
    # -----------------------------
    numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns
    scaler_path = os.path.join(MODEL_DIR, 'standard_scaler.pkl')

    if is_train:
        scaler = StandardScaler()
        X[numeric_cols] = scaler.fit_transform(X[numeric_cols])
        joblib.dump(scaler, scaler_path)
    else:
        scaler = joblib.load(scaler_path)
        X[numeric_cols] = scaler.transform(X[numeric_cols])

    # -----------------------------
    # Target
    # -----------------------------
    y = df['resume_score']

    return X, y

# %%
X, y = preprocess_data(df, is_train=True)

# %%
def perform_eda(df):
   
    plt.figure(figsize=(18, 12))

    # -----------------------------
    # Plot 1: Target Distribution
    # -----------------------------
    plt.subplot(2, 3, 1)
    sns.histplot(df['resume_score'], kde=True)
    plt.title('Distribution of Resume Score')

    # -----------------------------
    # Plot 2: Degree vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 2)
    sns.boxplot(
        x='degree',
        y='resume_score',
        data=df
    )
    plt.title('Degree vs Resume Score')

    # -----------------------------
    # Plot 3: Years of Experience vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 3)
    sns.scatterplot(
        x='years_experience',
        y='resume_score',
        data=df
    )
    plt.title('Experience vs Resume Score')

    # -----------------------------
    # Plot 4: Internship Distribution
    # -----------------------------
    plt.subplot(2, 3, 4)
    sns.countplot(
        x='internship',
        data=df
    )
    plt.title('Internship Distribution')

    # -----------------------------
    # Plot 5: Skills Count vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 5)
    sns.scatterplot(
        x='skills_count',
        y='resume_score',
        hue='github_portfolio',
        data=df
    )
    plt.title('Skills Count vs Resume Score')

    # -----------------------------
    # Plot 6: Interview Calls vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 6)
    sns.boxplot(
        x='interview_calls',
        y='resume_score',
        data=df
    )
    plt.title('Interview Calls vs Resume Score')

    plt.tight_layout()
    plt.savefig('resume_eda_plots.png')
    plt.show()

    print("EDA plots saved as 'resume_eda_plots.png'")

# %%
perform_eda(df)
# Out:
# EDA plots saved as 'resume_eda_plots.png'

# %%
def split_train_test(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )
    
    print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
    print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test(X, y)
# Out:
# X_train: (160, 8), X_test: (40, 8)
# y_train: (160,), y_test: (40,)

# %%
# Ensure results folder exists
os.makedirs("results", exist_ok=True)

# Global DataFrame to track regression metrics
regression_metrics_df = pd.DataFrame(columns=['Algorithm', 'MAE', 'MSE', 'RMSE', 'R2'])

def Calculate_Regression_Metrics(algorithm, y_pred, y_test):
    
    global regression_metrics_df  # Ensure we update the global DataFrame
    
    # Metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Save to global DataFrame
    regression_metrics_df.loc[len(regression_metrics_df)] = [algorithm, mae, mse, rmse, r2]

    # Print metrics
    print(f"{algorithm} Mean Absolute Error (MAE): {mae:.4f}")
    print(f"{algorithm} Mean Squared Error (MSE): {mse:.4f}")
    print(f"{algorithm} Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"{algorithm} R² Score: {r2:.4f}")

    # Scatter plot: Actual vs Predicted
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
    plt.xlabel("Actual Passengers Affected")
    plt.ylabel("Predicted Passengers Affected")
    plt.title(f"{algorithm} - Actual vs Predicted")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"results/{algorithm.replace(' ', '_')}_actual_vs_predicted.png")
    plt.show()

# %%
def train_elasticnet_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    l1_ratio=0.5,
    max_iter=2000
):
    model_path = os.path.join(
        MODEL_DIR,
        f'elasticnet_regressor_alpha_{alpha}_l1_{l1_ratio}.pkl'
    )

    if os.path.exists(model_path):
        print("Loading Elastic Net Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Elastic Net Regressor...")
        model = ElasticNet(
            alpha=alpha,
            l1_ratio=l1_ratio,
            max_iter=max_iter,
            random_state=42
        )
        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Elastic Net Regressor",
        y_pred,
        y_test
    )

    return model

# %%
elasticnet = train_elasticnet_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    l1_ratio=0.5
)
# Out:
# Loading Elastic Net Regressor...
# Elastic Net Regressor Mean Absolute Error (MAE): 3.8965
# Elastic Net Regressor Mean Squared Error (MSE): 21.8248
# Elastic Net Regressor Root Mean Squared Error (RMSE): 4.6717
# Elastic Net Regressor R² Score: 0.7998

# %%
def train_extra_trees_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    n_estimators=300,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1
):
    model_path = os.path.join(
        MODEL_DIR,
        'extra_trees_regressor.pkl'
    )

    if os.path.exists(model_path):
        print("Loading Extra Trees Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Extra Trees Regressor...")
        model = ExtraTreesRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=42,
            n_jobs=-1
        )
        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Extra Trees Regressor",
        y_pred,
        y_test
    )

    return model

# %%
train_extra_trees_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    n_estimators=300,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1
)
# Out:
# Loading Extra Trees Regressor...
# Extra Trees Regressor Mean Absolute Error (MAE): 3.3661
# Extra Trees Regressor Mean Squared Error (MSE): 22.7224
# Extra Trees Regressor Root Mean Squared Error (RMSE): 4.7668
# Extra Trees Regressor R² Score: 0.7915
# ExtraTreesRegressor(n_estimators=300, n_jobs=-1, random_state=42)

# %%
def train_lasso_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    max_iter=1000
):
    model_path = os.path.join(
        MODEL_DIR,
        f'lasso_regressor_alpha_{alpha}.pkl'
    )

    if os.path.exists(model_path):
        print("Loading Lasso Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Lasso Regressor...")
        model = Lasso(
            alpha=alpha,
            max_iter=max_iter,
            random_state=42
        )
        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # Clip predictions to valid range (0–100 for resume score)
    y_pred = np.clip(y_pred, 0, 100)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Lasso Regressor",
        y_pred,
        y_test
    )

    return model

# %%
train_lasso_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    max_iter=1000
)
# Out:
# Loading Lasso Regressor...
# Lasso Regressor Mean Absolute Error (MAE): 3.4152
# Lasso Regressor Mean Squared Error (MSE): 18.6980
# Lasso Regressor Root Mean Squared Error (RMSE): 4.3241
# Lasso Regressor R² Score: 0.8285
# Lasso(random_state=42)

# %%
def train_stacking_regressor(
    X_train,
    y_train,
    X_test,
    y_test
):
    model_path = os.path.join(MODEL_DIR, 'stacking_regressor.pkl')

    if os.path.exists(model_path):
        print("Loading Stacking Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Stacking Regressor...")

        # -----------------------------
        # Base Learners
        # -----------------------------
        base_estimators = [
            ('ridge', Ridge(alpha=1.0)),
            ('theilsen', TheilSenRegressor(random_state=42)),
        ]

        # -----------------------------
        # Meta Learner
        # -----------------------------
        meta_model = Ridge(alpha=0.5)

        # -----------------------------
        # Stacking Model
        # -----------------------------
        model = StackingRegressor(
            estimators=base_estimators,
            final_estimator=meta_model,
            cv=5,
            n_jobs=-1,
            passthrough=False
        )

        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # Optional: clip resume score
#    y_pred = np.clip(y_pred, 0, 100)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Stacking Regressor",
        y_pred,
        y_test
    )

    return model

# %%
Stacking = train_stacking_regressor(
    X_train,
    y_train,
    X_test,
    y_test
)
# Out:
# Loading Stacking Regressor...
# Stacking Regressor Mean Absolute Error (MAE): 0.9012
# Stacking Regressor Mean Squared Error (MSE): 1.9899
# Stacking Regressor Root Mean Squared Error (RMSE): 1.4106
# Stacking Regressor R² Score: 0.9817

# %% [markdown]
# # Predictions

# %%
testdata = pd.read_csv('Dataset/testdata.csv')
testdata
# Out:
#    candidate_id degree  years_experience  projects_count  certifications  \
# 0          C049    BSc                 6               0               1
# 1          C140  MTech                 8               8               2
# 2          C043  MTech                 8               7               2
# 3          C196  MTech                 0               5               2
# 4          C189    MCA                 8               2               0
# 5          C195  MTech                 2              10               5
# 6          C162  BTech                 5               6               2
# 7          C186  MTech                 4               9               0
# 8          C090    MCA                 7               8               6
# 9          C029  MTech                 1               3               1
# 10         C136    MCA                 4               0               4
# 11         C102  BTech                 3              10               1
# 12         C088  MTech                 2               7               1
# 13         C141  MTech                 1               7               0
# 14         C119    MCA                 3               7               4
# 15         C176  MTech                 5               1               0
# 16         C125  MTech                 1               7               0
# 17         C107  MTech                 4               7               0
# 18         C122    MCA                 5               5               4
# 19         C028    MCA                 7              11               0
#
#     skills_count internship github_portfolio  interview_calls
# 0             14         No              Yes                5
# 1              9         No               No                7
# 2              5        Yes               No                7
# 3              9        Yes               No                3
# 4             18        Yes               No                8
# 5             20        Yes               No                8
# 6             12         No              Yes                7
# 7             15        Yes               No                6
# 8             11         No               No                7
# 9             10         No              Yes                3
# 10             5         No               No                2
# 11            12        Yes              Yes                5
# 12            15         No               No                4
# 13             8        Yes               No                4
# 14             8         No              Yes                7
# 15            19         No              Yes                4
# 16            20         No              Yes                6
# 17            18         No               No                5
# 18            16         No               No                6
# 19             7        Yes               No                8

# %%
def preprocess_test_data(testdata):
    
    testdata = testdata.copy()

    # -----------------------------
    # Load saved encoders and scaler
    # -----------------------------
    degree_encoder = joblib.load(os.path.join(MODEL_DIR, 'degree_encoder.pkl'))
    internship_encoder = joblib.load(os.path.join(MODEL_DIR, 'internship_encoder.pkl'))
    github_encoder = joblib.load(os.path.join(MODEL_DIR, 'github_portfolio_encoder.pkl'))
    scaler = joblib.load(os.path.join(MODEL_DIR, 'standard_scaler.pkl'))

    # -----------------------------
    # Encode categorical features
    # -----------------------------
    testdata['degree'] = degree_encoder.transform(
        testdata['degree'].astype(str)
    )

    testdata['internship'] = internship_encoder.transform(
        testdata['internship'].astype(str)
    )

    testdata['github_portfolio'] = github_encoder.transform(
        testdata['github_portfolio'].astype(str)
    )

    # -----------------------------
    # Prepare feature matrix
    # -----------------------------
    X_test_preprocessed = testdata.drop(
        columns=['resume_score', 'candidate_id'],
        errors='ignore'
    )

    # -----------------------------
    # Scale numeric features
    # -----------------------------
    numeric_cols = X_test_preprocessed.select_dtypes(
        include=['int64', 'float64']
    ).columns

    X_test_preprocessed[numeric_cols] = scaler.transform(
        X_test_preprocessed[numeric_cols]
    )

    return X_test_preprocessed

# %%
# Preprocess test data
X_test_new = preprocess_test_data(testdata)

# Load trained stacking model
model = joblib.load(
    os.path.join(MODEL_DIR, 'stacking_regressor.pkl')
)

# Predict resume score
y_pred = model.predict(X_test_new)

# Clip predictions (0–100)
y_pred = np.clip(y_pred, 0, 100)

# Add predictions to test dataframe
testdata['predicted_resume_score'] = y_pred

testdata
# Out:
#    candidate_id degree  years_experience  projects_count  certifications  \
# 0          C049    BSc                 6               0               1
# 1          C140  MTech                 8               8               2
# 2          C043  MTech                 8               7               2
# 3          C196  MTech                 0               5               2
# 4          C189    MCA                 8               2               0
# 5          C195  MTech                 2              10               5
# 6          C162  BTech                 5               6               2
# 7          C186  MTech                 4               9               0
# 8          C090    MCA                 7               8               6
# 9          C029  MTech                 1               3               1
# 10         C136    MCA                 4               0               4
# 11         C102  BTech                 3              10               1
# 12         C088  MTech                 2               7               1
# 13         C141  MTech                 1               7               0
# 14         C119    MCA                 3               7               4
# 15         C176  MTech                 5               1               0
# 16         C125  MTech                 1               7               0
# 17         C107  MTech                 4               7               0
# 18         C122    MCA                 5               5               4
# 19         C028    MCA                 7              11               0
#
#     skills_count internship github_portfolio  interview_calls  \
# 0             14         No              Yes                5
# 1              9         No               No                7
# 2              5        Yes               No                7
# 3              9        Yes               No                3
# 4             18        Yes               No                8
# 5             20        Yes               No                8
# 6             12         No              Yes                7
# 7             15        Yes               No                6
# 8             11         No               No                7
# 9             10         No              Yes                3
# 10             5         No               No                2
# 11            12        Yes              Yes                5
# 12            15         No               No                4
# 13             8        Yes               No                4
# 14             8         No              Yes                7
# 15            19         No              Yes                4
# 16            20         No              Yes                6
# 17            18         No               No                5
# 18            16         No               No                6
# 19             7        Yes               No                8
#
#     predicted_resume_score
# 0                85.374088
# 1                99.264640
# 2                99.489162
# 3                70.318005
# 4                97.912262
# 5               100.000000
# 6                94.063530
# 7                93.363776
# 8               100.000000
# 9                68.191761
# 10               72.755981
# 11               96.385611
# 12               79.555608
# 13               71.561782
# 14               90.266673
# 15               85.625916
# 16               82.673986
# 17               87.116650
# 18               96.782221
# 19               99.299540

# %%
MODEL_DIR = "models"
RESULTS_DIR = "results"

Path(MODEL_DIR).mkdir(exist_ok=True)
Path(RESULTS_DIR).mkdir(exist_ok=True)

# %%
def load_dataset(file_path):
    """Load the dataset from a CSV file."""
    try:
        df = pd.read_csv(file_path)
        print(f"Dataset loaded successfully with shape: {df.shape}")
        return df
    except FileNotFoundError:
        print(f"Error: File {file_path} not found.")
        return None
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return None

# %%
MODEL_DIR = "models"
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
df = pd.read_csv('Dataset/resume_skills_vs_interview_calls.csv')
df
# Out:
#     candidate_id degree  years_experience  projects_count  certifications  \
# 0           C001  BTech                 0              11               2
# 1           C002  BTech                 8               1               4
# 2           C003    BSc                 3               8               4
# 3           C004    MCA                 4              12               6
# 4           C005  MTech                 2               3               6
# ..           ...    ...               ...             ...             ...
# 195         C196  MTech                 0               5               2
# 196         C197    BSc                 3               2               1
# 197         C198  BTech                 5              12               4
# 198         C199    BSc                 2              11               3
# 199         C200    BSc                 7               9               2
#
#      skills_count internship github_portfolio  resume_score  interview_calls
# 0              11        Yes              Yes            89                6
# 1              17        Yes              Yes           100                6
# 2               4        Yes               No            89                4
# 3               4        Yes               No           100                7
# 4              14        Yes              Yes            96                6
# ..            ...        ...              ...           ...              ...
# 195             9        Yes               No            70                3
# 196             6         No              Yes            70                4
# 197             8         No              Yes           100                6
# 198             5         No               No            84                6
# 199            18        Yes              Yes           100                7
#
# [200 rows x 10 columns]

# %%
MODEL_DIR = "models"
os.makedirs(MODEL_DIR, exist_ok=True)


def preprocess_data(df, is_train=True):
    df = df.copy()

    # -----------------------------
    # Drop ID Column
    # -----------------------------
    if 'candidate_id' in df.columns:
        df.drop(columns=['candidate_id'], inplace=True)

    # -----------------------------
    # Encode Categorical Features
    # -----------------------------
    categorical_cols = [
        'degree',
        'internship',
        'github_portfolio'
    ]

    for col in categorical_cols:
        encoder_path = os.path.join(MODEL_DIR, f"{col}_encoder.pkl")

        if is_train:
            le = LabelEncoder()
            df[col] = le.fit_transform(df[col].astype(str))
            joblib.dump(le, encoder_path)
        else:
            le = joblib.load(encoder_path)
            df[col] = le.transform(df[col].astype(str))

    # -----------------------------
    # Feature Matrix
    # -----------------------------
    X = df.drop(columns=['resume_score'])

    # -----------------------------
    # Standard Scaling
    # -----------------------------
    numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns
    scaler_path = os.path.join(MODEL_DIR, 'standard_scaler.pkl')

    if is_train:
        scaler = StandardScaler()
        X[numeric_cols] = scaler.fit_transform(X[numeric_cols])
        joblib.dump(scaler, scaler_path)
    else:
        scaler = joblib.load(scaler_path)
        X[numeric_cols] = scaler.transform(X[numeric_cols])

    # -----------------------------
    # Target
    # -----------------------------
    y = df['resume_score']

    return X, y

# %%
X, y = preprocess_data(df, is_train=True)

# %%
def perform_eda(df):
   
    plt.figure(figsize=(18, 12))

    # -----------------------------
    # Plot 1: Target Distribution
    # -----------------------------
    plt.subplot(2, 3, 1)
    sns.histplot(df['resume_score'], kde=True)
    plt.title('Distribution of Resume Score')

    # -----------------------------
    # Plot 2: Degree vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 2)
    sns.boxplot(
        x='degree',
        y='resume_score',
        data=df
    )
    plt.title('Degree vs Resume Score')

    # -----------------------------
    # Plot 3: Years of Experience vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 3)
    sns.scatterplot(
        x='years_experience',
        y='resume_score',
        data=df
    )
    plt.title('Experience vs Resume Score')

    # -----------------------------
    # Plot 4: Internship Distribution
    # -----------------------------
    plt.subplot(2, 3, 4)
    sns.countplot(
        x='internship',
        data=df
    )
    plt.title('Internship Distribution')

    # -----------------------------
    # Plot 5: Skills Count vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 5)
    sns.scatterplot(
        x='skills_count',
        y='resume_score',
        hue='github_portfolio',
        data=df
    )
    plt.title('Skills Count vs Resume Score')

    # -----------------------------
    # Plot 6: Interview Calls vs Resume Score
    # -----------------------------
    plt.subplot(2, 3, 6)
    sns.boxplot(
        x='interview_calls',
        y='resume_score',
        data=df
    )
    plt.title('Interview Calls vs Resume Score')

    plt.tight_layout()
    plt.savefig('resume_eda_plots.png')
    plt.show()

    print("EDA plots saved as 'resume_eda_plots.png'")

# %%
perform_eda(df)
# Out:
# EDA plots saved as 'resume_eda_plots.png'

# %%
def split_train_test(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )
    
    print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
    print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test(X, y)
# Out:
# X_train: (160, 8), X_test: (40, 8)
# y_train: (160,), y_test: (40,)

# %%
# Ensure results folder exists
os.makedirs("results", exist_ok=True)

# Global DataFrame to track regression metrics
regression_metrics_df = pd.DataFrame(columns=['Algorithm', 'MAE', 'MSE', 'RMSE', 'R2'])

def Calculate_Regression_Metrics(algorithm, y_pred, y_test):
    
    global regression_metrics_df  # Ensure we update the global DataFrame
    
    # Metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Save to global DataFrame
    regression_metrics_df.loc[len(regression_metrics_df)] = [algorithm, mae, mse, rmse, r2]

    # Print metrics
    print(f"{algorithm} Mean Absolute Error (MAE): {mae:.4f}")
    print(f"{algorithm} Mean Squared Error (MSE): {mse:.4f}")
    print(f"{algorithm} Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"{algorithm} R² Score: {r2:.4f}")

    # Scatter plot: Actual vs Predicted
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
    plt.xlabel("Actual Passengers Affected")
    plt.ylabel("Predicted Passengers Affected")
    plt.title(f"{algorithm} - Actual vs Predicted")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"results/{algorithm.replace(' ', '_')}_actual_vs_predicted.png")
    plt.show()

# %%
def train_elasticnet_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    l1_ratio=0.5,
    max_iter=2000
):
    model_path = os.path.join(
        MODEL_DIR,
        f'elasticnet_regressor_alpha_{alpha}_l1_{l1_ratio}.pkl'
    )

    if os.path.exists(model_path):
        print("Loading Elastic Net Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Elastic Net Regressor...")
        model = ElasticNet(
            alpha=alpha,
            l1_ratio=l1_ratio,
            max_iter=max_iter,
            random_state=42
        )
        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Elastic Net Regressor",
        y_pred,
        y_test
    )

    return model

# %%
elasticnet = train_elasticnet_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    l1_ratio=0.5
)
# Out:
# Loading Elastic Net Regressor...
# Elastic Net Regressor Mean Absolute Error (MAE): 3.8965
# Elastic Net Regressor Mean Squared Error (MSE): 21.8248
# Elastic Net Regressor Root Mean Squared Error (RMSE): 4.6717
# Elastic Net Regressor R² Score: 0.7998

# %%
def train_extra_trees_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    n_estimators=300,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1
):
    model_path = os.path.join(
        MODEL_DIR,
        'extra_trees_regressor.pkl'
    )

    if os.path.exists(model_path):
        print("Loading Extra Trees Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Extra Trees Regressor...")
        model = ExtraTreesRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=42,
            n_jobs=-1
        )
        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Extra Trees Regressor",
        y_pred,
        y_test
    )

    return model

# %%
train_extra_trees_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    n_estimators=300,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1
)
# Out:
# Loading Extra Trees Regressor...
# Extra Trees Regressor Mean Absolute Error (MAE): 3.3661
# Extra Trees Regressor Mean Squared Error (MSE): 22.7224
# Extra Trees Regressor Root Mean Squared Error (RMSE): 4.7668
# Extra Trees Regressor R² Score: 0.7915
# ExtraTreesRegressor(n_estimators=300, n_jobs=-1, random_state=42)

# %%
def train_lasso_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    max_iter=1000
):
    model_path = os.path.join(
        MODEL_DIR,
        f'lasso_regressor_alpha_{alpha}.pkl'
    )

    if os.path.exists(model_path):
        print("Loading Lasso Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Lasso Regressor...")
        model = Lasso(
            alpha=alpha,
            max_iter=max_iter,
            random_state=42
        )
        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # Clip predictions to valid range (0–100 for resume score)
    y_pred = np.clip(y_pred, 0, 100)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Lasso Regressor",
        y_pred,
        y_test
    )

    return model

# %%
train_lasso_regressor(
    X_train,
    y_train,
    X_test,
    y_test,
    alpha=1.0,
    max_iter=1000
)
# Out:
# Loading Lasso Regressor...
# Lasso Regressor Mean Absolute Error (MAE): 3.4152
# Lasso Regressor Mean Squared Error (MSE): 18.6980
# Lasso Regressor Root Mean Squared Error (RMSE): 4.3241
# Lasso Regressor R² Score: 0.8285
# Lasso(random_state=42)

# %%
def train_stacking_regressor(
    X_train,
    y_train,
    X_test,
    y_test
):
    model_path = os.path.join(MODEL_DIR, 'stacking_regressor.pkl')

    if os.path.exists(model_path):
        print("Loading Stacking Regressor...")
        model = joblib.load(model_path)
    else:
        print("Training Stacking Regressor...")

        # -----------------------------
        # Base Learners
        # -----------------------------
        base_estimators = [
            ('ridge', Ridge(alpha=1.0)),
            ('theilsen', TheilSenRegressor(random_state=42)),
        ]

        # -----------------------------
        # Meta Learner
        # -----------------------------
        meta_model = Ridge(alpha=0.5)

        # -----------------------------
        # Stacking Model
        # -----------------------------
        model = StackingRegressor(
            estimators=base_estimators,
            final_estimator=meta_model,
            cv=5,
            n_jobs=-1,
            passthrough=False
        )

        model.fit(X_train, y_train)
        joblib.dump(model, model_path)
        print(f"Model saved to {model_path}")

    # -----------------------------
    # Predictions
    # -----------------------------
    y_pred = model.predict(X_test)

    # Optional: clip resume score
#    y_pred = np.clip(y_pred, 0, 100)

    # -----------------------------
    # Evaluate
    # -----------------------------
    Calculate_Regression_Metrics(
        "Stacking Regressor",
        y_pred,
        y_test
    )

    return model

# %%
Stacking = train_stacking_regressor(
    X_train,
    y_train,
    X_test,
    y_test
)
# Out:
# Loading Stacking Regressor...
# Stacking Regressor Mean Absolute Error (MAE): 0.9012
# Stacking Regressor Mean Squared Error (MSE): 1.9899
# Stacking Regressor Root Mean Squared Error (RMSE): 1.4106
# Stacking Regressor R² Score: 0.9817

# %% [markdown]
# # Predictions

# %%
testdata = pd.read_csv('Dataset/testdata.csv')
testdata
# Out:
#    candidate_id degree  years_experience  projects_count  certifications  \
# 0          C049    BSc                 6               0               1
# 1          C140  MTech                 8               8               2
# 2          C043  MTech                 8               7               2
# 3          C196  MTech                 0               5               2
# 4          C189    MCA                 8               2               0
# 5          C195  MTech                 2              10               5
# 6          C162  BTech                 5               6               2
# 7          C186  MTech                 4               9               0
# 8          C090    MCA                 7               8               6
# 9          C029  MTech                 1               3               1
# 10         C136    MCA                 4               0               4
# 11         C102  BTech                 3              10               1
# 12         C088  MTech                 2               7               1
# 13         C141  MTech                 1               7               0
# 14         C119    MCA                 3               7               4
# 15         C176  MTech                 5               1               0
# 16         C125  MTech                 1               7               0
# 17         C107  MTech                 4               7               0
# 18         C122    MCA                 5               5               4
# 19         C028    MCA                 7              11               0
#
#     skills_count internship github_portfolio  interview_calls
# 0             14         No              Yes                5
# 1              9         No               No                7
# 2              5        Yes               No                7
# 3              9        Yes               No                3
# 4             18        Yes               No                8
# 5             20        Yes               No                8
# 6             12         No              Yes                7
# 7             15        Yes               No                6
# 8             11         No               No                7
# 9             10         No              Yes                3
# 10             5         No               No                2
# 11            12        Yes              Yes                5
# 12            15         No               No                4
# 13             8        Yes               No                4
# 14             8         No              Yes                7
# 15            19         No              Yes                4
# 16            20         No              Yes                6
# 17            18         No               No                5
# 18            16         No               No                6
# 19             7        Yes               No                8

# %%
def preprocess_test_data(testdata):
    
    testdata = testdata.copy()

    # -----------------------------
    # Load saved encoders and scaler
    # -----------------------------
    degree_encoder = joblib.load(os.path.join(MODEL_DIR, 'degree_encoder.pkl'))
    internship_encoder = joblib.load(os.path.join(MODEL_DIR, 'internship_encoder.pkl'))
    github_encoder = joblib.load(os.path.join(MODEL_DIR, 'github_portfolio_encoder.pkl'))
    scaler = joblib.load(os.path.join(MODEL_DIR, 'standard_scaler.pkl'))

    # -----------------------------
    # Encode categorical features
    # -----------------------------
    testdata['degree'] = degree_encoder.transform(
        testdata['degree'].astype(str)
    )

    testdata['internship'] = internship_encoder.transform(
        testdata['internship'].astype(str)
    )

    testdata['github_portfolio'] = github_encoder.transform(
        testdata['github_portfolio'].astype(str)
    )

    # -----------------------------
    # Prepare feature matrix
    # -----------------------------
    X_test_preprocessed = testdata.drop(
        columns=['resume_score', 'candidate_id'],
        errors='ignore'
    )

    # -----------------------------
    # Scale numeric features
    # -----------------------------
    numeric_cols = X_test_preprocessed.select_dtypes(
        include=['int64', 'float64']
    ).columns

    X_test_preprocessed[numeric_cols] = scaler.transform(
        X_test_preprocessed[numeric_cols]
    )

    return X_test_preprocessed

# %%
# Preprocess test data
X_test_new = preprocess_test_data(testdata)

# Load trained stacking model
model = joblib.load(
    os.path.join(MODEL_DIR, 'stacking_regressor.pkl')
)

# Predict resume score
y_pred = model.predict(X_test_new)

# Clip predictions (0–100)
y_pred = np.clip(y_pred, 0, 100)

# Add predictions to test dataframe
testdata['predicted_resume_score'] = y_pred

testdata
# Out:
#    candidate_id degree  years_experience  projects_count  certifications  \
# 0          C049    BSc                 6               0               1
# 1          C140  MTech                 8               8               2
# 2          C043  MTech                 8               7               2
# 3          C196  MTech                 0               5               2
# 4          C189    MCA                 8               2               0
# 5          C195  MTech                 2              10               5
# 6          C162  BTech                 5               6               2
# 7          C186  MTech                 4               9               0
# 8          C090    MCA                 7               8               6
# 9          C029  MTech                 1               3               1
# 10         C136    MCA                 4               0               4
# 11         C102  BTech                 3              10               1
# 12         C088  MTech                 2               7               1
# 13         C141  MTech                 1               7               0
# 14         C119    MCA                 3               7               4
# 15         C176  MTech                 5               1               0
# 16         C125  MTech                 1               7               0
# 17         C107  MTech                 4               7               0
# 18         C122    MCA                 5               5               4
# 19         C028    MCA                 7              11               0
#
#     skills_count internship github_portfolio  interview_calls  \
# 0             14         No              Yes                5
# 1              9         No               No                7
# 2              5        Yes               No                7
# 3              9        Yes               No                3
# 4             18        Yes               No                8
# 5             20        Yes               No                8
# 6             12         No              Yes                7
# 7             15        Yes               No                6
# 8             11         No               No                7
# 9             10         No              Yes                3
# 10             5         No               No                2
# 11            12        Yes              Yes                5
# 12            15         No               No                4
# 13             8        Yes               No                4
# 14             8         No              Yes                7
# 15            19         No              Yes                4
# 16            20         No              Yes                6
# 17            18         No               No                5
# 18            16         No               No                6
# 19             7        Yes               No                8
#
#     predicted_resume_score
# 0                85.374088
# 1                99.264640
# 2                99.489162
# 3                70.318005
# 4                97.912262
# 5               100.000000
# 6                94.063530
# 7                93.363776
# 8               100.000000
# 9                68.191761
# 10               72.755981
# 11               96.385611
# 12               79.555608
# 13               71.561782
# 14               90.266673
# 15               85.625916
# 16               82.673986
# 17               87.116650
# 18               96.782221
# 19               99.299540
